# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/Users/johann/Documents/Uni/ITSP/utils'

# %%
data = pd.read_csv("../data/raw/wnut16_weak/twitter_user_data/data/gender_classifier_dfe_791531.csv")

# %%
# restrict to 10000 sequences
data = data.iloc[:10000, :]

# %%
data.head()
# Out:
#      unit_id  golden unit_state  trusted_judgments     last_judgment_at  \
# 0  815719226   False  finalized                  3  2015-10-26T23:24:00
# 1  815719227   False  finalized                  3  2015-10-26T23:30:00
# 2  815719228   False  finalized                  3  2015-10-26T23:33:00
# 3  815719229   False  finalized                  3  2015-10-26T23:10:00
# 4  815719230   False  finalized                  3  2015-10-27T01:15:00
#
#    gender  gender_confidence  profile_yn  profile_yn_confidence  \
# 0    male             1.0000        True                    1.0
# 1    male             1.0000        True                    1.0
# 2    male             0.6625        True                    1.0
# 3    male             1.0000        True                    1.0
# 4  female             1.0000        True                    1.0
#
#                created  ...  \
# 0  2013-12-05T01:48:00  ...
# 1  2012-10-01T13:51:00  ...
# 2  2014-11-28T11:30:00  ...
# ...

# %%
data_train = pd.DataFrame({'sequence' : data['text']})

# %%
data_train['sequence_tok'] = data_train['sequence'].apply(lambda x: x.split(' '))

# %%
data_train.head()
# Out:
#                                             sequence  \
# 0  Robbie E Responds To Critics After Win Against...
# 1  ���It felt like they were my friends and I was...
# 2  i absolutely adore when louis starts the songs...
# 3  Hi @JordanSpieth - Looking at the url - do you...
# 4  Watching Neighbours on Sky+ catching up with t...
#
#                                         sequence_tok
# 0  [Robbie, E, Responds, To, Critics, After, Win,...
# 1  [���It, felt, like, they, were, my, friends, a...
# 2  [i, absolutely, adore, when, louis, starts, th...
# 3  [Hi, @JordanSpieth, -, Looking, at, the, url, ...
# 4  [Watching, Neighbours, on, Sky+, catching, up,...

# %%
data_train.to_csv('../data/WNUT16/__init/weak/data_train.csv')
